# %%
import numpy as np
from numpy import array
import pandas as pd
import pickle
import matplotlib.pyplot as plt
import string
import os
from PIL import Image
import glob
from pickle import dump, load
from time import time
from keras.preprocessing import sequence
from keras.models import Sequential
from keras.layers import LSTM, Embedding, TimeDistributed, Dense, RepeatVector,\
                         Activation, Flatten, Reshape, concatenate, Dropout, BatchNormalization
from keras.optimizers import Adam, RMSprop
from keras.layers.wrappers import Bidirectional
from keras.layers.merge import add
from keras.applications.inception_v3 import InceptionV3
from keras.preprocessing import image
from keras.models import Model
from keras import Input, layers
from keras import optimizers
from keras.applications.inception_v3 import preprocess_input
from keras.preprocessing.text import Tokenizer
from keras.preprocessing.sequence import pad_sequences
from keras.utils import to_categorical
# Out:
# Using TensorFlow backend.

# %%
def load_doc(filename):
    file = open(filename, 'r')
    text = file.read()
    file.close()
    return text

filename = "Flickr_Data/Flickr_TextData/Flickr8k.token.txt"
doc = load_doc(filename)
print(doc[:300])
# Out:
# 1000268201_693b08cb0e.jpg#0	A child in a pink dress is climbing up a set of stairs in an entry way .
# 1000268201_693b08cb0e.jpg#1	A girl going into a wooden building .
# 1000268201_693b08cb0e.jpg#2	A little girl climbing into a wooden playhouse .
# 1000268201_693b08cb0e.jpg#3	A little girl climbing the s

# %%
def load_descriptions(doc):
    mapping = dict()
    for line in doc.split('\n'):
        tokens = line.split()
        if len(line) < 2:
            continue
        image_id, image_desc = tokens[0], tokens[1:]
        image_id = image_id.split('.')[0]
        image_desc = ' '.join(image_desc)
        if image_id not in mapping:
            mapping[image_id] = list()
        mapping[image_id].append(image_desc)
    return mapping


descriptions = load_descriptions(doc)
print('Loaded: %d ' % len(descriptions))
# Out:
# Loaded: 8092

# %%
def clean_descriptions(descriptions):
    table = str.maketrans('', '', string.punctuation)
    for key, desc_list in descriptions.items():
        for i in range(len(desc_list)):
            desc = desc_list[i]
            desc = desc.split()
            desc = [word.lower() for word in desc]
            desc = [w.translate(table) for w in desc]
            desc = [word for word in desc if len(word)>1]
            desc = [word for word in desc if word.isalpha()]
            desc_list[i] =  ' '.join(desc)
clean_descriptions(descriptions)

# %%
def to_vocabulary(descriptions):
    all_desc = set()
    for key in descriptions.keys():
        [all_desc.update(d.split()) for d in descriptions[key]]
    return all_desc
vocabulary = to_vocabulary(descriptions)
print('Original Vocabulary Size: %d' % len(vocabulary))
# Out:
# Original Vocabulary Size: 8763

# %%
def save_descriptions(descriptions, filename):
    lines = list()
    for key, desc_list in descriptions.items():
        for desc in desc_list:
            lines.append(key + ' ' + desc)
    data = '\n'.join(lines)
    file = open(filename, 'w')
    file.write(data)
    file.close()
save_descriptions(descriptions, 'descriptions.txt')

# %%
def load_set(filename):
    doc = load_doc(filename)
    dataset = list()
    for line in doc.split('\n'):
        if len(line) < 1:
            continue
        identifier = line.split('.')[0]
        dataset.append(identifier)
    return set(dataset)
filename = 'Flickr_Data/Flickr_TextData/Flickr_8k.trainImages.txt'
train = load_set(filename)
print('Dataset: %d' % len(train))
# Out:
# Dataset: 6000

# %%
images = 'Flickr_Data/Images/'
img = glob.glob(images + '*.jpg')

# %%
train_images_file = 'Flickr_Data/Flickr_TextData/Flickr_8k.trainImages.txt'
train_images = set(open(train_images_file, 'r').read().strip().split('\n'))
train_img = []
for i in img: 
    if i[len(images):] in train_images: 
        train_img.append(i)

# %%
test_images_file = 'Flickr_Data/Flickr_TextData/Flickr_8k.testImages.txt'
test_images = set(open(test_images_file, 'r').read().strip().split('\n'))
test_img = []
for i in img: 
    if i[len(images):] in test_images: 
        test_img.append(i)         
test_img
# Out:
# ['Flickr_Data/Images\\1056338697_4f7d7ce270.jpg',
#  'Flickr_Data/Images\\106490881_5a2dd9b7bd.jpg',
#  'Flickr_Data/Images\\1082379191_ec1e53f996.jpg',
#  'Flickr_Data/Images\\1084040636_97d9633581.jpg',
#  'Flickr_Data/Images\\1096395242_fc69f0ae5a.jpg',
#  'Flickr_Data/Images\\1107246521_d16a476380.jpg',
#  'Flickr_Data/Images\\1119015538_e8e796281e.jpg',
#  'Flickr_Data/Images\\1122944218_8eb3607403.jpg',
#  'Flickr_Data/Images\\1131800850_89c7ffd477.jpg',
#  'Flickr_Data/Images\\1131932671_c8d17751b3.jpg',
#  'Flickr_Data/Images\\113678030_87a6a6e42e.jpg',
#  'Flickr_Data/Images\\114051287_dd85625a04.jpg',
#  'Flickr_Data/Images\\115684808_cb01227802.jpg',
#  'Flickr_Data/Images\\1167669558_87a8a467d6.jpg',
#  'Flickr_Data/Images\\1174525839_7c1e6cfa86.jpg',
#  'Flickr_Data/Images\\1174629344_a2e1a2bdbf.jpg',
#  'Flickr_Data/Images\\1220401002_3f44b1f3f7.jpg',
#  'Flickr_Data/Images\\1224851143_33bcdd299c.jpg',
#  'Flickr_Data/Images\\1237985362_dbafc59280.jpg',
#  'Flickr_Data/Images\\1248940539_46d33ed487.jpg',
#  'Flickr_Data/Images\\1258913059_07c613f7ff.jpg',
#  'Flickr_Data/Images\\1262583859_653f1469a9.jpg',
#  'Flickr_Data/Images\\1267711451_e2a754b4f8.jpg',
#  'Flickr_Data/Images\\127488876_f2d2a89588.jpg',
#  'Flickr_Data/Images\\127490019_7c5c08cb11.jpg',
#  'Flickr_Data/Images\\1282392036_5a0328eb86.jpg',
#  'Flickr_Data/Images\\1287073593_f3d2a62455.jpg',
#  'Flickr_Data/Images\\1287475186_2dee85f1a5.jpg',
#  'Flickr_Data/Images\\1298295313_db1f4c6522.jpg',
#  'Flickr_Data/Images\\1311388430_4ab0cd1a1f.jpg',
#  'Flickr_Data/Images\\1317292658_ba29330a0b.jpg',
#  'Flickr_Data/Images\\1322323208_c7ecb742c6.jpg',
#  'Flickr_Data/Images\\132489044_3be606baf7.jpg',
#  'Flickr_Data/Images\\1329832826_432538d331.jpg',
#  'Flickr_Data/Images\\1332722096_1e3de8ae70.jpg',
#  'Flickr_Data/Images\\1339596997_8ac29c1841.jpg',
#  'Flickr_Data/Images\\1343426964_cde3fb54e8.jpg',
#  'Flickr_Data/Images\\1348304997_afe60a61df.jpg',
#  'Flickr_Data/Images\\1352410176_af6b139734.jpg',
#  'Flickr_Data/Images\\1356796100_b265479721.jpg',
#  'Flickr_Data/Images\\136552115_6dc3e7231c.jpg',
#  'Flickr_Data/Images\\136644343_0e2b423829.jpg',
#  'Flickr_Data/Images\\136886677_6026c622eb.jpg',
#  'Flickr_Data/Images\\1386964743_9e80d96b05.jpg',
#  'Flickr_Data/Images\\138718600_f430ebca17.jpg',
#  'Flickr_Data/Images\\1387785218_cee67735f5.jpg',
#  'Flickr_Data/Images\\1389264266_8170bc1c54.jpg',
#  'Flickr_Data/Images\\1392272228_cf104086e6.jpg',
#  'Flickr_Data/Images\\1394368714_3bc7c19969.jpg',
#  'Flickr_Data/Images\\1402640441_81978e32a9.jpg',
#  'Flickr_Data/Images\\1404832008_68e432665b.jpg',
#  'Flickr_Data/Images\\1408958345_68eea9a4e4.jpg',
#  'Flickr_Data/Images\\1415591512_a84644750c.jpg',
#  'Flickr_Data/Images\\1417031097_ab656bc4bd.jpg',
#  'Flickr_Data/Images\\1425069308_488e5fcf9d.jpg',
#  'Flickr_Data/Images\\1427391496_ea512cbe7f.jpg',
#  'Flickr_Data/Images\\1432179046_8e3d75cf81.jpg',
#  'Flickr_Data/Images\\1433142189_cda8652603.jpg',
#  'Flickr_Data/Images\\143688283_a96ded20f1.jpg',
#  'Flickr_Data/Images\\1446053356_a924b4893f.jpg',
#  'Flickr_Data/Images\\1456393634_74022d9056.jpg',
#  'Flickr_Data/Images\\1461667284_041c8a2475.jpg',
#  'Flickr_Data/Images\\1467533293_a2656cc000.jpg',
#  'Flickr_Data/Images\\1472230829_803818a383.jpg',
#  'Flickr_Data/Images\\1472882567_33dc14c8b6.jpg',
#  'Flickr_Data/Images\\1490213660_9ea45550cf.jpg',
#  'Flickr_Data/Images\\1490670858_e122df2560.jpg',
#  'Flickr_Data/Images\\1499581619_a5f65a882c.jpg',
#  'Flickr_Data/Images\\150387174_24825cf871.jpg',
#  'Flickr_Data/Images\\1509786421_f03158adfc.jpg',
#  'Flickr_Data/Images\\1517721825_10176d0683.jpg',
#  'Flickr_Data/Images\\1523984678_edd68464da.jpg',
#  'Flickr_Data/Images\\1536774449_e16b1b6382.jpg',
#  'Flickr_Data/Images\\1547883892_e29b3db42e.jpg',
#  'Flickr_Data/Images\\154871781_ae77696b77.jpg',
#  'Flickr_Data/Images\\1554713437_61b64527dd.jpg',
#  'Flickr_Data/Images\\1561658940_a947f2446a.jpg',
#  'Flickr_Data/Images\\1572532018_64c030c974.jpg',
#  'Flickr_Data/Images\\1584315962_5b0b45d02d.jpg',
#  'Flickr_Data/Images\\160792599_6a7ec52516.jpg',
#  'Flickr_Data/Images\\1626754053_81126b67b6.jpg',
#  'Flickr_Data/Images\\1659358141_0433c9bf99.jpg',
#  'Flickr_Data/Images\\166507476_9be5b9852a.jpg',
#  'Flickr_Data/Images\\1674612291_7154c5ab61.jpg',
#  'Flickr_Data/Images\\1679617928_a73c1769be.jpg',
#  'Flickr_Data/Images\\1682079482_9a72fa57fa.jpg',
#  'Flickr_Data/Images\\170100272_d820db2199.jpg',
#  'Flickr_Data/Images\\1714316707_8bbaa2a2ba.jpg',
#  'Flickr_Data/Images\\172097782_f0844ec317.jpg',
#  'Flickr_Data/Images\\1764955991_5e53a28c87.jpg',
#  'Flickr_Data/Images\\1765164972_92dac06fa9.jpg',
#  'Flickr_Data/Images\\1772859261_236c09b861.jpg',
#  'Flickr_Data/Images\\1773928579_5664a810dc.jpg',
#  'Flickr_Data/Images\\1786425974_c7c5ad6aa1.jpg',
#  'Flickr_Data/Images\\180094434_b0f244832d.jpg',
#  'Flickr_Data/Images\\180506881_de0f59770f.jpg',
#  'Flickr_Data/Images\\1808370027_2088394eb4.jpg',
#  'Flickr_Data/Images\\1836335410_de8313a64e.jpg',
#  'Flickr_Data/Images\\1897025969_0c41688fa6.jpg',
#  'Flickr_Data/Images\\189721896_1ffe76d89e.jpg',
#  'Flickr_Data/Images\\191003285_edd8d0cf58.jpg',
#  'Flickr_Data/Images\\1917265421_aeccf1ca38.jpg',
#  'Flickr_Data/Images\\1962729184_6996e128e7.jpg',
#  'Flickr_Data/Images\\197107117_4b438b1872.jpg',
#  'Flickr_Data/Images\\197504190_fd1fc3d4b7.jpg',
#  'Flickr_Data/Images\\1982852140_56425fa7a2.jpg',
#  'Flickr_Data/Images\\1998457059_c9ac9a1e1a.jpg',
#  'Flickr_Data/Images\\200771289_31902164a7.jpg',
#  'Flickr_Data/Images\\2021613437_d99731f986.jpg',
#  'Flickr_Data/Images\\2041867793_552819a40b.jpg',
#  'Flickr_Data/Images\\2049051050_20359a434a.jpg',
#  'Flickr_Data/Images\\2054869561_ff723e9eab.jpg',
#  'Flickr_Data/Images\\2061144717_5b3a1864f0.jpg',
#  'Flickr_Data/Images\\2061354254_faa5bd294b.jpg',
#  'Flickr_Data/Images\\2064790732_219e52e19c.jpg',
#  'Flickr_Data/Images\\2073105823_6dacade004.jpg',
#  'Flickr_Data/Images\\2073964624_52da3a0fc4.jpg',
#  'Flickr_Data/Images\\2075321027_c8fcbaf581.jpg',
#  'Flickr_Data/Images\\2077079696_03380d218b.jpg',
#  'Flickr_Data/Images\\2078311270_f01c9eaf4c.jpg',
#  'Flickr_Data/Images\\2083434441_a93bc6306b.jpg',
#  'Flickr_Data/Images\\2084217208_7bd9bc85e5.jpg',
#  'Flickr_Data/Images\\2086513494_dbbcb583e7.jpg',
#  'Flickr_Data/Images\\2089426086_7acc98a3a8.jpg',
#  'Flickr_Data/Images\\2096771662_984441d20d.jpg',
#  'Flickr_Data/Images\\2100816230_ff866fb352.jpg',
#  'Flickr_Data/Images\\2101457132_69c950bc45.jpg',
#  'Flickr_Data/Images\\2102360862_264452db8e.jpg',
#  'Flickr_Data/Images\\2103568100_5d018c495b.jpg',
#  'Flickr_Data/Images\\2105756457_a100d8434e.jpg',
#  'Flickr_Data/Images\\2112921744_92bf706805.jpg',
#  'Flickr_Data/Images\\211295363_49010ca38d.jpg',
#  'Flickr_Data/Images\\2120383553_5825333a3f.jpg',
#  'Flickr_Data/Images\\2120411340_104eb610b1.jpg',
#  'Flickr_Data/Images\\2124040721_bffc0a091a.jpg',
#  'Flickr_Data/Images\\2128119486_4407061c40.jpg',
#  'Flickr_Data/Images\\2140182410_8e2a06fbda.jpg',
#  'Flickr_Data/Images\\2148916767_644ea6a7fa.jpg',
#  'Flickr_Data/Images\\215214751_e913b6ff09.jpg',
#  'Flickr_Data/Images\\2160266952_a2ab39191b.jpg',
#  'Flickr_Data/Images\\2162564553_96de62c7e6.jpg',
#  'Flickr_Data/Images\\2167644298_100ca79f54.jpg',
#  'Flickr_Data/Images\\2170222061_e8bce4a32d.jpg',
#  'Flickr_Data/Images\\2176980976_7054c99621.jpg',
#  'Flickr_Data/Images\\2182488373_df73c7cc09.jpg',
#  'Flickr_Data/Images\\2183227136_8bb657846b.jpg',
#  'Flickr_Data/Images\\2189995738_352607a63b.jpg',
#  'Flickr_Data/Images\\219070971_ae43410b9e.jpg',
#  'Flickr_Data/Images\\2192131110_8a40e7c028.jpg',
#  'Flickr_Data/Images\\219301555_17883a51bd.jpg',
#  'Flickr_Data/Images\\2194286203_5dc620006a.jpg',
#  'Flickr_Data/Images\\2194494220_bb2178832c.jpg',
#  'Flickr_Data/Images\\2196107384_361d73a170.jpg',
#  'Flickr_Data/Images\\2196316998_3b2d63f01f.jpg',
#  'Flickr_Data/Images\\2196846255_2c1635359a.jpg',
#  'Flickr_Data/Images\\2197275664_fabcf3424b.jpg',
#  'Flickr_Data/Images\\2204550058_2707d92338.jpg',
#  'Flickr_Data/Images\\2206960564_325ed0c7ae.jpg',
#  'Flickr_Data/Images\\2207244634_1db1a1890b.jpg',
#  'Flickr_Data/Images\\2208067635_39a03834ca.jpg',
#  'Flickr_Data/Images\\2208310655_a3d83080c5.jpg',
#  'Flickr_Data/Images\\2215136723_960edfea49.jpg',
#  'Flickr_Data/Images\\2216695423_1362cb25f3.jpg',
#  'Flickr_Data/Images\\2218609886_892dcd6915.jpg',
#  'Flickr_Data/Images\\2224450291_4c133fabe8.jpg',
#  'Flickr_Data/Images\\2225231022_1632d0a5aa.jpg',
#  'Flickr_Data/Images\\2228022180_9597b2a458.jpg',
#  'Flickr_Data/Images\\2229179070_dc8ea8582e.jpg',
#  'Flickr_Data/Images\\223299142_521aedf9e7.jpg',
#  'Flickr_Data/Images\\2238019823_79318d1f11.jpg',
#  'Flickr_Data/Images\\2238759450_6475641bdb.jpg',
#  'Flickr_Data/Images\\2239938351_43c73c887c.jpg',
#  'Flickr_Data/Images\\224369028_b1ac40d1fa.jpg',
#  'Flickr_Data/Images\\2247889670_413db8094b.jpg',
#  'Flickr_Data/Images\\2248487950_c62d0c81a9.jpg',
#  'Flickr_Data/Images\\2251747182_6b67a3ab8b.jpg',
#  'Flickr_Data/Images\\2256133102_e2c8314ecb.jpg',
#  'Flickr_Data/Images\\2265096094_8cc34d669c.jpg',
#  'Flickr_Data/Images\\226607225_44d696db6b.jpg',
#  'Flickr_Data/Images\\2271755053_e1b1ec8442.jpg',
#  'Flickr_Data/Images\\2274992140_bb9e868bb8.jpg',
#  'Flickr_Data/Images\\2280525192_81911f2b00.jpg',
#  'Flickr_Data/Images\\2283966256_70317e1759.jpg',
#  'Flickr_Data/Images\\2285570521_05015cbf4b.jpg',
#  'Flickr_Data/Images\\2288099178_41091aa00c.jpg',
#  'Flickr_Data/Images\\2289068031_fe26990183.jpg',
#  'Flickr_Data/Images\\2292406847_f366350600.jpg',
#  'Flickr_Data/Images\\2295216243_0712928988.jpg',
#  'Flickr_Data/Images\\2295750198_6d152d7ceb.jpg',
#  'Flickr_Data/Images\\229862312_1a0ba19dab.jpg',
#  'Flickr_Data/Images\\2300168895_a9b83e16fc.jpg',
#  'Flickr_Data/Images\\2301525531_edde12d673.jpg',
#  'Flickr_Data/Images\\2306674172_dc07c7f847.jpg',
#  'Flickr_Data/Images\\2307118114_c258e3a47e.jpg',
#  'Flickr_Data/Images\\2308271254_27fb466eb4.jpg',
#  'Flickr_Data/Images\\2308978137_bfe776d541.jpg',
#  'Flickr_Data/Images\\2309860995_c2e2a0feeb.jpg',
#  'Flickr_Data/Images\\2310126952_7dc86d88f6.jpg',
#  'Flickr_Data/Images\\2311690895_0d6efe11c8.jpg',
#  'Flickr_Data/Images\\2317714088_bcd081f926.jpg',
#  'Flickr_Data/Images\\2333288869_8c01e4c859.jpg',
#  'Flickr_Data/Images\\2339106348_2df90aa6a9.jpg',
#  'Flickr_Data/Images\\2340206885_58754a799a.jpg',
#  'Flickr_Data/Images\\2343525685_3eba3b6686.jpg',
#  'Flickr_Data/Images\\2345984157_724823b1e4.jpg',
#  'Flickr_Data/Images\\2346401538_f5e8da66fc.jpg',
#  'Flickr_Data/Images\\2351479551_e8820a1ff3.jpg',
#  'Flickr_Data/Images\\2354540393_a149722680.jpg',
#  'Flickr_Data/Images\\2358554995_54ed3baa83.jpg',
#  'Flickr_Data/Images\\2358561039_e215a8d6cd.jpg',
#  'Flickr_Data/Images\\2358898017_24496b80e8.jpg',
#  'Flickr_Data/Images\\2370481277_a3085614c9.jpg',
#  'Flickr_Data/Images\\2373234213_4ebe9c4ee5.jpg',
#  'Flickr_Data/Images\\2374652725_32f90fa15c.jpg',
#  'Flickr_Data/Images\\2378149488_648e5deeac.jpg',
#  'Flickr_Data/Images\\2384353160_f395e9a54b.jpg',
#  'Flickr_Data/Images\\2393264648_a280744f97.jpg',
#  'Flickr_Data/Images\\2396025708_e4a72e2558.jpg',
#  'Flickr_Data/Images\\2396691909_6b8c2f7c44.jpg',
#  'Flickr_Data/Images\\2398605966_1d0c9e6a20.jpg',
#  'Flickr_Data/Images\\241031254_0c6f30e3d1.jpg',
#  'Flickr_Data/Images\\2410320522_d967f0b75c.jpg',
#  'Flickr_Data/Images\\241345811_46b5f157d4.jpg',
#  'Flickr_Data/Images\\241345844_69e1c22464.jpg',
#  'Flickr_Data/Images\\241345905_5826a72da1.jpg',
#  'Flickr_Data/Images\\241346508_0b3907a95b.jpg',
#  'Flickr_Data/Images\\241346971_c100650320.jpg',
#  'Flickr_Data/Images\\241347204_007d83e252.jpg',
#  'Flickr_Data/Images\\241347760_d44c8d3a01.jpg',
#  'Flickr_Data/Images\\2414397449_2ac3b78e0d.jpg',
#  'Flickr_Data/Images\\2415803492_56a673dc25.jpg',
#  'Flickr_Data/Images\\2419221084_01a14176b4.jpg',
#  'Flickr_Data/Images\\2421446839_fe7d46c177.jpg',
#  'Flickr_Data/Images\\2431470169_0eeba7d602.jpg',
#  'Flickr_Data/Images\\2431832075_00aa1a4457.jpg',
#  'Flickr_Data/Images\\2435685480_a79d42e564.jpg',
#  'Flickr_Data/Images\\2436081047_bca044c1d3.jpg',
#  'Flickr_Data/Images\\2443380641_7b38d18f5b.jpg',
#  'Flickr_Data/Images\\2445283938_ff477c7952.jpg',
#  'Flickr_Data/Images\\244571201_0339d8e8d1.jpg',
#  'Flickr_Data/Images\\2447284966_d6bbdb4b6e.jpg',
#  'Flickr_Data/Images\\2450299735_62c095f40e.jpg',
#  'Flickr_Data/Images\\2450453051_f1d4a78ab4.jpg',
#  'Flickr_Data/Images\\245252561_4f20f1c89e.jpg',
#  'Flickr_Data/Images\\2453971388_76616b6a82.jpg',
#  'Flickr_Data/Images\\2458269558_277012780d.jpg',
#  'Flickr_Data/Images\\245895500_a4eb97af02.jpg',
#  'Flickr_Data/Images\\246055693_ccb69ac5c6.jpg',
#  'Flickr_Data/Images\\2460797929_66446c13db.jpg',
#  'Flickr_Data/Images\\2461616306_3ee7ac1b4b.jpg',
#  'Flickr_Data/Images\\2470486377_c3a39ccb7b.jpg',
#  'Flickr_Data/Images\\2472980433_210ec62874.jpg',
#  'Flickr_Data/Images\\2473689180_e9d8fd656a.jpg',
#  'Flickr_Data/Images\\2473738924_eca928d12f.jpg',
#  'Flickr_Data/Images\\2473791980_805c819bd4.jpg',
#  'Flickr_Data/Images\\2475162978_2c51048dca.jpg',
#  'Flickr_Data/Images\\247637795_fdf26a03cf.jpg',
#  'Flickr_Data/Images\\247704641_d883902277.jpg',
#  'Flickr_Data/Images\\2479162876_a5ce3306af.jpg',
#  'Flickr_Data/Images\\2479652566_8f9fac8af5.jpg',
#  'Flickr_Data/Images\\2480327661_fb69829f57.jpg',
#  'Flickr_Data/Images\\2480850054_de3433b54a.jpg',
#  'Flickr_Data/Images\\2482629385_f370b290d1.jpg',
#  'Flickr_Data/Images\\2484190118_e89363c465.jpg',
#  'Flickr_Data/Images\\2490768374_45d94fc658.jpg',
#  'Flickr_Data/Images\\249394748_2e4acfbbb5.jpg',
#  'Flickr_Data/Images\\2495931537_9b8d4474b6.jpg',
#  'Flickr_Data/Images\\2496370758_a3fbc49837.jpg',
#  'Flickr_Data/Images\\2497420371_74788d7ba1.jpg',
#  'Flickr_Data/Images\\2498897831_0bbb5d5b51.jpg',
#  'Flickr_Data/Images\\2501595799_6316001e89.jpg',
#  'Flickr_Data/Images\\2502905671_c6039804ab.jpg',
#  'Flickr_Data/Images\\2505988632_9541f15583.jpg',
#  'Flickr_Data/Images\\2510020918_b2ca0fb2aa.jpg',
#  'Flickr_Data/Images\\2511019188_ca71775f2d.jpg',
#  'Flickr_Data/Images\\2518508760_68d8df7365.jpg',
#  'Flickr_Data/Images\\2521770311_3086ca90de.jpg',
#  'Flickr_Data/Images\\2522297487_57edf117f7.jpg',
#  'Flickr_Data/Images\\2525270674_4ab536e7ec.jpg',
#  'Flickr_Data/Images\\2526041608_a9775ab8d7.jpg',
#  'Flickr_Data/Images\\2526585002_10987a63f3.jpg',
#  'Flickr_Data/Images\\2529116152_4331dabf50.jpg',
#  'Flickr_Data/Images\\2533424347_cf2f84872b.jpg',
#  'Flickr_Data/Images\\2533642917_a5eace85e6.jpg',
#  'Flickr_Data/Images\\2534502836_7a75305655.jpg',
#  'Flickr_Data/Images\\2541104331_a2d65cfa54.jpg',
#  'Flickr_Data/Images\\2542662402_d781dd7f7c.jpg',
#  'Flickr_Data/Images\\254295381_d98fa049f4.jpg',
#  'Flickr_Data/Images\\2543589122_ec3e55f434.jpg',
#  'Flickr_Data/Images\\2544182005_3aa1332bf9.jpg',
#  'Flickr_Data/Images\\2544426580_317b1f1f73.jpg',
#  'Flickr_Data/Images\\2549968784_39bfbe44f9.jpg',
#  'Flickr_Data/Images\\2553550034_5901aa9d6c.jpg',
#  'Flickr_Data/Images\\2554081584_233bdf289a.jpg',
#  'Flickr_Data/Images\\2559503010_84f20b3bc9.jpg',
#  'Flickr_Data/Images\\2559921948_06af25d566.jpg',
#  'Flickr_Data/Images\\256085101_2c2617c5d0.jpg',
#  'Flickr_Data/Images\\2573625591_70291c894a.jpg',
#  'Flickr_Data/Images\\2575647360_f5de38c751.jpg',
#  'Flickr_Data/Images\\2577972703_a22c5f2a87.jpg',
#  'Flickr_Data/Images\\2581066814_179d28f306.jpg',
#  'Flickr_Data/Images\\2587818583_4aa8e7b174.jpg',
#  'Flickr_Data/Images\\2588927489_f4da2f11ec.jpg',
#  'Flickr_Data/Images\\2589241160_3832440850.jpg',
#  'Flickr_Data/Images\\2594042571_2e4666507e.jpg',
#  'Flickr_Data/Images\\2594902417_f65d8866a8.jpg',
#  'Flickr_Data/Images\\2595186208_9b16fa0ee3.jpg',
#  'Flickr_Data/Images\\2599444370_9e40103027.jpg',
#  'Flickr_Data/Images\\2600867924_cd502fc911.jpg',
#  'Flickr_Data/Images\\2602085456_d1beebcb29.jpg',
#  'Flickr_Data/Images\\2602258549_7401a3cdae.jpg',
#  'Flickr_Data/Images\\2603792708_18a97bac97.jpg',
#  'Flickr_Data/Images\\260520547_944f9f4c91.jpg',
#  'Flickr_Data/Images\\2607462776_78e639d891.jpg',
#  'Flickr_Data/Images\\260828892_7925d27865.jpg',
#  'Flickr_Data/Images\\2608289957_044849f73e.jpg',
#  'Flickr_Data/Images\\2610447973_89227ff978.jpg',
#  'Flickr_Data/Images\\2612488996_9450de0e54.jpg',
#  'Flickr_Data/Images\\261490838_2f3ac98b12.jpg',
#  'Flickr_Data/Images\\2616643090_4f2d2d1a44.jpg',
#  'Flickr_Data/Images\\2621415349_ef1a7e73be.jpg',
#  'Flickr_Data/Images\\2623930900_b9df917b82.jpg',
#  'Flickr_Data/Images\\2631300484_be8621d17b.jpg',
#  'Flickr_Data/Images\\263854883_0f320c1562.jpg',
#  'Flickr_Data/Images\\2641770481_c98465ff35.jpg',
#  'Flickr_Data/Images\\2644430445_47c985a2ee.jpg',
#  'Flickr_Data/Images\\2646046871_c3a5dbb971.jpg',
#  'Flickr_Data/Images\\2646116932_232573f030.jpg',
#  'Flickr_Data/Images\\2647049174_0fb47cee2e.jpg',
#  'Flickr_Data/Images\\2648165716_02e2e74fd6.jpg',
#  'Flickr_Data/Images\\2649406158_ded6be38de.jpg',
#  'Flickr_Data/Images\\2652522323_9218afd8c2.jpg',
#  'Flickr_Data/Images\\2654514044_a70a6e2c21.jpg',
#  'Flickr_Data/Images\\2657484284_daa07a3a1b.jpg',
#  'Flickr_Data/Images\\2660008870_b672a4c76a.jpg',
#  'Flickr_Data/Images\\2662845514_8620aaee96.jpg',
#  'Flickr_Data/Images\\2663794355_e726ec7e05.jpg',
#  'Flickr_Data/Images\\2666179615_f05a9d8331.jpg',
#  'Flickr_Data/Images\\2666205903_8d287669e1.jpg',
#  'Flickr_Data/Images\\2667015110_1670324a33.jpg',
#  'Flickr_Data/Images\\2675685200_0913d84d9b.jpg',
#  'Flickr_Data/Images\\2676764246_c58205a365.jpg',
#  'Flickr_Data/Images\\2677656448_6b7e7702af.jpg',
#  'Flickr_Data/Images\\2682382530_f9f8fd1e89.jpg',
#  'Flickr_Data/Images\\2683963310_20dcd5e566.jpg',
#  'Flickr_Data/Images\\2689001252_e0016c89f0.jpg',
#  'Flickr_Data/Images\\2693425189_47740c22ed.jpg',
#  'Flickr_Data/Images\\2696866120_254a0345bc.jpg',
#  'Flickr_Data/Images\\2698666984_13e17236ae.jpg',
#  'Flickr_Data/Images\\2704934519_457dc38986.jpg',
#  'Flickr_Data/Images\\2706766641_a9df81969d.jpg',
#  'Flickr_Data/Images\\270724499_107481c88f.jpg',
#  'Flickr_Data/Images\\2707873672_15e6b5d54b.jpg',
#  'Flickr_Data/Images\\270816949_ffad112278.jpg',
#  'Flickr_Data/Images\\2708686056_1b8f356264.jpg',
#  'Flickr_Data/Images\\2712787899_d85048eb6a.jpg',
#  'Flickr_Data/Images\\2715035273_8fc8b1291c.jpg',
#  'Flickr_Data/Images\\2718024196_3ff660416a.jpg',
#  'Flickr_Data/Images\\2718495608_d8533e3ac5.jpg',
#  'Flickr_Data/Images\\2723477522_d89f5ac62b.jpg',
#  'Flickr_Data/Images\\2729655904_1dd01922fb.jpg',
#  'Flickr_Data/Images\\2731171552_4a808c7d5a.jpg',
#  'Flickr_Data/Images\\2735558076_0d7bbc18fc.jpg',
#  'Flickr_Data/Images\\2739331794_4ae78f69a0.jpg',
#  'Flickr_Data/Images\\2748729903_3c7c920c4d.jpg',
#  'Flickr_Data/Images\\2757803246_8aa3499d26.jpg',
#  'Flickr_Data/Images\\2759860913_f75b39d783.jpg',
#  'Flickr_Data/Images\\2762301555_48a0d0aa24.jpg',
#  'Flickr_Data/Images\\2763044275_aa498eb88b.jpg',
#  'Flickr_Data/Images\\2764178773_d63b502812.jpg',
#  'Flickr_Data/Images\\2774430374_fee1d793e7.jpg',
#  'Flickr_Data/Images\\2774554310_007e980a90.jpg',
#  'Flickr_Data/Images\\2782433864_5a0c311d87.jpg',
#  'Flickr_Data/Images\\2788945468_74a9618cfa.jpg',
#  'Flickr_Data/Images\\2796801478_8ebd7e550b.jpg',
#  'Flickr_Data/Images\\2797149878_bb8e27ecf9.jpg',
#  'Flickr_Data/Images\\279728508_6bd7281f3c.jpg',
#  'Flickr_Data/Images\\2806710650_e201acd913.jpg',
#  'Flickr_Data/Images\\280706862_14c30d734a.jpg',
#  'Flickr_Data/Images\\2813033949_e19fa08805.jpg',
#  'Flickr_Data/Images\\2813992915_f732cf8539.jpg',
#  'Flickr_Data/Images\\2815256108_fc1302117d.jpg',
#  'Flickr_Data/Images\\2822290399_97c809d43b.jpg',
#  'Flickr_Data/Images\\2830869109_c4e403eae6.jpg',
#  'Flickr_Data/Images\\2831217847_555b2f95ca.jpg',
#  'Flickr_Data/Images\\2839038702_e168128665.jpg',
#  'Flickr_Data/Images\\2842865689_e37256d9ce.jpg',
#  'Flickr_Data/Images\\2843695880_eeea6c67db.jpg',
#  'Flickr_Data/Images\\2844018783_524b08e5aa.jpg',
#  'Flickr_Data/Images\\2844641033_dab3715a99.jpg',
#  'Flickr_Data/Images\\2847615962_c330bded6e.jpg',
#  'Flickr_Data/Images\\2854207034_1f00555703.jpg',
#  'Flickr_Data/Images\\2854959952_3991a385ab.jpg',
#  'Flickr_Data/Images\\2856080862_95d793fa9d.jpg',
#  'Flickr_Data/Images\\2860872588_f2c7b30e1a.jpg',
#  'Flickr_Data/Images\\2861932486_52befd8592.jpg',
#  'Flickr_Data/Images\\2862004252_53894bb28b.jpg',
#  'Flickr_Data/Images\\2866254827_9a8f592017.jpg',
#  'Flickr_Data/Images\\2868575889_2c030aa8ae.jpg',
#  'Flickr_Data/Images\\2869491449_1041485a6b.jpg',
#  'Flickr_Data/Images\\2870875612_2cbb9e4a3c.jpg',
#  'Flickr_Data/Images\\2876993733_cb26107d18.jpg',
#  'Flickr_Data/Images\\2877503811_4e311253ec.jpg',
#  'Flickr_Data/Images\\2878190821_6e4e03dc5f.jpg',
#  'Flickr_Data/Images\\2878272032_fda05ffac7.jpg',
#  'Flickr_Data/Images\\2883099128_0b056eed9e.jpg',
#  'Flickr_Data/Images\\2884301336_dc8e974431.jpg',
#  'Flickr_Data/Images\\2884420269_225d27f242.jpg',
#  'Flickr_Data/Images\\2885387575_9127ea10f1.jpg',
#  'Flickr_Data/Images\\2886411666_72d8b12ce4.jpg',
#  'Flickr_Data/Images\\2890113532_ab2003d74e.jpg',
#  'Flickr_Data/Images\\2891617125_f939f604c7.jpg',
#  'Flickr_Data/Images\\2892995070_39f3c9a56e.jpg',
#  'Flickr_Data/Images\\2893374123_087f98d58a.jpg',
#  'Flickr_Data/Images\\2894217628_f1a4153dca.jpg',
#  'Flickr_Data/Images\\2900274587_f2cbca4c58.jpg',
#  'Flickr_Data/Images\\2901074943_041aba4607.jpg',
#  'Flickr_Data/Images\\2901880865_3fd7b66a45.jpg',
#  'Flickr_Data/Images\\2902269566_419d9f1d8e.jpg',
#  'Flickr_Data/Images\\2905942129_2b4bf59bc0.jpg',
#  'Flickr_Data/Images\\2909875716_25c8652614.jpg',
#  'Flickr_Data/Images\\2909955251_4b326a46a7.jpg',
#  'Flickr_Data/Images\\2910758605_73a3f5a5c2.jpg',
#  'Flickr_Data/Images\\2913965136_2d00136697.jpg',
#  'Flickr_Data/Images\\2914206497_5e36ac6324.jpg',
#  'Flickr_Data/Images\\2918769188_565dd48060.jpg',
#  'Flickr_Data/Images\\2921094201_2ed70a7963.jpg',
#  'Flickr_Data/Images\\2922222717_12195af92d.jpg',
#  'Flickr_Data/Images\\2922973230_5a769ef92a.jpg',
#  'Flickr_Data/Images\\2924259848_effb4dcb82.jpg',
#  'Flickr_Data/Images\\2926233397_71e617f3a3.jpg',
#  'Flickr_Data/Images\\2926595608_69b22be8d4.jpg',
#  'Flickr_Data/Images\\2928152792_b16c73434a.jpg',
#  'Flickr_Data/Images\\2929506802_5432054d77.jpg',
#  'Flickr_Data/Images\\2932740428_b15384f389.jpg',
#  'Flickr_Data/Images\\293327462_20dee0de56.jpg',
#  'Flickr_Data/Images\\2933637854_984614e18b.jpg',
#  'Flickr_Data/Images\\2933912528_52b05f84a1.jpg',
#  'Flickr_Data/Images\\2934359101_cdf57442dc.jpg',
#  'Flickr_Data/Images\\2938120171_970564e3d8.jpg',
#  'Flickr_Data/Images\\2938747424_64e64784f0.jpg',
#  'Flickr_Data/Images\\293879742_5fe0ffd894.jpg',
#  'Flickr_Data/Images\\293881927_ac62900fd4.jpg',
#  'Flickr_Data/Images\\2943023421_e297f05e11.jpg',
#  'Flickr_Data/Images\\2944362789_aebbc22db4.jpg',
#  'Flickr_Data/Images\\2944836001_b38b516286.jpg',
#  'Flickr_Data/Images\\2944952557_8484f0da8f.jpg',
#  'Flickr_Data/Images\\2945036454_280fa5b29f.jpg',
#  'Flickr_Data/Images\\2949982320_c704b31626.jpg',
#  'Flickr_Data/Images\\2950905787_f2017d3e49.jpg',
#  'Flickr_Data/Images\\2953015871_cae796b6e7.jpg',
#  'Flickr_Data/Images\\2963573792_dd51b5fbfb.jpg',
#  'Flickr_Data/Images\\2966552760_e65b22cd26.jpg',
#  'Flickr_Data/Images\\2968182121_b3b491df85.jpg',
#  'Flickr_Data/Images\\2971431335_e192613db4.jpg',
#  'Flickr_Data/Images\\2981702521_2459f2c1c4.jpg',
#  'Flickr_Data/Images\\2984174290_a915748d77.jpg',
#  'Flickr_Data/Images\\2985679744_75a7102aab.jpg',
#  'Flickr_Data/Images\\2991575785_bd4868e215.jpg',
#  'Flickr_Data/Images\\2991994415_504d1c0a03.jpg',
#  'Flickr_Data/Images\\2991994607_06f24ec7a6.jpg',
#  'Flickr_Data/Images\\2994179598_a45c2732b5.jpg',
#  'Flickr_Data/Images\\2999730677_0cfa1c146e.jpg',
#  'Flickr_Data/Images\\300314926_0b2e4b64f5.jpg',
#  'Flickr_Data/Images\\3003691049_f4363c2d5c.jpg',
#  'Flickr_Data/Images\\3004823335_9b82cbd8a7.jpg',
#  'Flickr_Data/Images\\300550441_f44ec3701a.jpg',
#  'Flickr_Data/Images\\300577375_26cc2773a1.jpg',
#  'Flickr_Data/Images\\3006093003_c211737232.jpg',
#  'Flickr_Data/Images\\300922408_05a4f9938c.jpg',
#  'Flickr_Data/Images\\3009644534_992e9ea2a7.jpg',
#  'Flickr_Data/Images\\3015863181_92ff43f4d8.jpg',
#  'Flickr_Data/Images\\3016606751_0e8be20abd.jpg',
#  'Flickr_Data/Images\\3017521547_f5ef8848e3.jpg',
#  'Flickr_Data/Images\\3019842612_8501c1791e.jpg',
#  'Flickr_Data/Images\\3024172109_a10198e1dd.jpg',
#  'Flickr_Data/Images\\3025549604_38b86198f5.jpg',
#  'Flickr_Data/Images\\3027397797_4f1d305ced.jpg',
#  'Flickr_Data/Images\\3028969146_26929ae0e8.jpg',
#  'Flickr_Data/Images\\302983277_69a4e732e4.jpg',
#  'Flickr_Data/Images\\3030294889_78b2ccbe51.jpg',
#  'Flickr_Data/Images\\3030566410_393c36a6c5.jpg',
#  'Flickr_Data/Images\\3040033126_9f4b88261b.jpg',
#  'Flickr_Data/Images\\3042380610_c5ea61eef8.jpg',
#  'Flickr_Data/Images\\3044500219_778f9f2b71.jpg',
#  'Flickr_Data/Images\\3044536048_e615466e7f.jpg',
#  'Flickr_Data/Images\\3044746136_8b89da5f40.jpg',
#  'Flickr_Data/Images\\3045613316_4e88862836.jpg',
#  'Flickr_Data/Images\\3047264346_e24601bfbf.jpg',
#  'Flickr_Data/Images\\3048597471_5697538daf.jpg',
#  'Flickr_Data/Images\\3051384385_c5c850c1f8.jpg',
#  'Flickr_Data/Images\\3052196390_c59dd24ca8.jpg',
#  'Flickr_Data/Images\\3053743109_a2d780c0d2.jpg',
#  'Flickr_Data/Images\\3058439373_9276a4702a.jpg',
#  'Flickr_Data/Images\\3061481868_d1e00b1f2e.jpg',
#  'Flickr_Data/Images\\3062173277_bfb5ef4c45.jpg',
#  'Flickr_Data/Images\\3064383768_f6838f57da.jpg',
#  'Flickr_Data/Images\\3070011270_390e597783.jpg',
#  'Flickr_Data/Images\\3070031806_3d587c2a66.jpg',
#  'Flickr_Data/Images\\3071676551_a65741e372.jpg',
#  'Flickr_Data/Images\\3072114570_e1c0127529.jpg',
#  'Flickr_Data/Images\\3072172967_630e9c69d0.jpg',
#  'Flickr_Data/Images\\307327914_f98f576adb.jpg',
#  'Flickr_Data/Images\\3074842262_62b1b2168c.jpg',
#  'Flickr_Data/Images\\3079787482_0757e9d167.jpg',
#  'Flickr_Data/Images\\3080056515_3013830309.jpg',
#  'Flickr_Data/Images\\308487515_7852928f90.jpg',
#  'Flickr_Data/Images\\3085226474_62aba51179.jpg',
#  'Flickr_Data/Images\\3085667767_66041b202e.jpg',
#  'Flickr_Data/Images\\3085667865_fa001816be.jpg',
#  'Flickr_Data/Images\\3095225232_2e6e6dc92e.jpg',
#  'Flickr_Data/Images\\309687244_4bdf3b591f.jpg',
#  'Flickr_Data/Images\\3099923914_fd450f6d51.jpg',
#  'Flickr_Data/Images\\3100251515_c68027cc22.jpg',
#  'Flickr_Data/Images\\3106026005_473a7b1c8c.jpg',
#  'Flickr_Data/Images\\3107513635_fe8a21f148.jpg',
#  'Flickr_Data/Images\\3108197858_441ff38565.jpg',
#  'Flickr_Data/Images\\3108732084_565b423162.jpg',
#  'Flickr_Data/Images\\3109704348_c6416244ce.jpg',
#  'Flickr_Data/Images\\3110649716_c17e14670e.jpg',
#  'Flickr_Data/Images\\311146855_0b65fdb169.jpg',
#  'Flickr_Data/Images\\3113322995_13781860f2.jpg',
#  'Flickr_Data/Images\\3114944484_28b5bb9842.jpg',
#  'Flickr_Data/Images\\3115174046_9e96b9ce47.jpg',
#  'Flickr_Data/Images\\3116769029_f5a76f04ba.jpg',
#  'Flickr_Data/Images\\3119076670_64b5340530.jpg',
#  'Flickr_Data/Images\\3119875880_22f9129a1c.jpg',
#  'Flickr_Data/Images\\3121521593_18f0ec14f7.jpg',
#  'Flickr_Data/Images\\3123351642_3794f2f601.jpg',
#  'Flickr_Data/Images\\3123463486_f5b36a3624.jpg',
#  'Flickr_Data/Images\\3125309108_1011486589.jpg',
#  'Flickr_Data/Images\\3128164023_ebe8da4c32.jpg',
#  'Flickr_Data/Images\\3135504530_0f4130d8f8.jpg',
#  'Flickr_Data/Images\\3138399980_d6ab8b2272.jpg',
#  'Flickr_Data/Images\\3139160252_75109e9e05.jpg',
#  'Flickr_Data/Images\\3139876823_859c7d7c23.jpg',
#  'Flickr_Data/Images\\3141293960_74459f0a24.jpg',
#  'Flickr_Data/Images\\3143155555_32b6d24f34.jpg',
#  'Flickr_Data/Images\\3143982558_9e2d44c155.jpg',
#  'Flickr_Data/Images\\3145967309_b33abe4d84.jpg',
#  'Flickr_Data/Images\\3149919755_f9272b10b3.jpg',
#  'Flickr_Data/Images\\3150742439_b8a352e1e0.jpg',
#  'Flickr_Data/Images\\3154641421_d1b9b8c24c.jpg',
#  'Flickr_Data/Images\\3155390408_8e1a81efb2.jpg',
#  'Flickr_Data/Images\\3155451946_c0862c70cb.jpg',
#  'Flickr_Data/Images\\3155987659_b9ea318dd3.jpg',
#  'Flickr_Data/Images\\3157847991_463e006a28.jpg',
#  'Flickr_Data/Images\\315880837_90db309bab.jpg',
#  'Flickr_Data/Images\\3159995270_17334ccb5b.jpg',
#  'Flickr_Data/Images\\3162045919_c2decbb69b.jpg',
#  'Flickr_Data/Images\\3167365436_c379bda282.jpg',
#  'Flickr_Data/Images\\3168123064_d1983b8f92.jpg',
#  'Flickr_Data/Images\\317109978_cb557802e1.jpg',
#  'Flickr_Data/Images\\317383917_d8bfa350b6.jpg',
#  'Flickr_Data/Images\\317488612_70ac35493b.jpg',
#  'Flickr_Data/Images\\3179336562_c3d0c0a3bd.jpg',
#  'Flickr_Data/Images\\3181701312_70a379ab6e.jpg',
#  'Flickr_Data/Images\\3182121297_38c99b2769.jpg',
#  'Flickr_Data/Images\\3185371756_ff4e9fa8a6.jpg',
#  'Flickr_Data/Images\\3185409663_95f6b958d8.jpg',
#  'Flickr_Data/Images\\3186073578_6e115f45f5.jpg',
#  'Flickr_Data/Images\\3186412658_2ab2ebd397.jpg',
#  'Flickr_Data/Images\\3187395715_f2940c2b72.jpg',
#  'Flickr_Data/Images\\3187492926_8aa85f80c6.jpg',
#  'Flickr_Data/Images\\3191135894_2b4bdabb6d.jpg',
#  'Flickr_Data/Images\\3192069971_83c5a90b4c.jpg',
#  'Flickr_Data/Images\\3192266178_f9bf5d3dba.jpg',
#  'Flickr_Data/Images\\3197917064_e679a44b8e.jpg',
#  'Flickr_Data/Images\\3197981073_3156963446.jpg',
#  'Flickr_Data/Images\\3200120942_59cfbb3437.jpg',
#  'Flickr_Data/Images\\3201427741_3033f5b625.jpg',
#  'Flickr_Data/Images\\3203453897_6317aac6ff.jpg',
#  'Flickr_Data/Images\\3203908917_53e53c03d1.jpg',
#  'Flickr_Data/Images\\3207358897_bfa61fa3c6.jpg',
#  'Flickr_Data/Images\\3208074567_ac44aeb3f3.jpg',
#  'Flickr_Data/Images\\3211556865_d1d9becf69.jpg',
#  'Flickr_Data/Images\\3213992947_3f3f967a9f.jpg',
#  'Flickr_Data/Images\\3214237686_6566b8b52f.jpg',
#  'Flickr_Data/Images\\3214573346_d3a57f0328.jpg',
#  'Flickr_Data/Images\\3214885227_2be09e7cfb.jpg',
#  'Flickr_Data/Images\\3216926094_bc975e84b9.jpg',
#  'Flickr_Data/Images\\3217187564_0ffd89dec1.jpg',
#  'Flickr_Data/Images\\3217266166_4e0091860b.jpg',
#  'Flickr_Data/Images\\3217620013_8b17873273.jpg',
#  'Flickr_Data/Images\\3217910740_d1d61c08ab.jpg',
#  'Flickr_Data/Images\\3218480482_66af7587c8.jpg',
#  'Flickr_Data/Images\\3220126881_b0a4f7cccb.jpg',
#  'Flickr_Data/Images\\3220161734_77f42734b9.jpg',
#  'Flickr_Data/Images\\3220650628_4ed964e5b4.jpg',
#  'Flickr_Data/Images\\3221036999_3f7b152d8a.jpg',
#  'Flickr_Data/Images\\3222041930_f642f49d28.jpg',
#  'Flickr_Data/Images\\3222055946_45f7293bb2.jpg',
#  'Flickr_Data/Images\\3223055565_68973f5d20.jpg',
#  'Flickr_Data/Images\\3223224391_be50bf4f43.jpg',
#  'Flickr_Data/Images\\3224227640_31865b3651.jpg',
#  'Flickr_Data/Images\\3225310099_d8e419ba56.jpg',
#  'Flickr_Data/Images\\3227148358_f152303584.jpg',
#  'Flickr_Data/Images\\3228069008_edb2961fc4.jpg',
#  'Flickr_Data/Images\\3232470286_903a61ea16.jpg',
#  'Flickr_Data/Images\\3234115903_f4dfc8fc75.jpg',
#  'Flickr_Data/Images\\3234401637_84e0d14414.jpg',
#  'Flickr_Data/Images\\3238951136_2a99f1a1a8.jpg',
#  'Flickr_Data/Images\\3239021459_a6b71bb400.jpg',
#  'Flickr_Data/Images\\324208502_674488bcea.jpg',
#  'Flickr_Data/Images\\3243588540_b418ac7eda.jpg',
#  'Flickr_Data/Images\\3244470342_c08f6bb17e.jpg',
#  'Flickr_Data/Images\\3244747165_17028936e0.jpg',
#  'Flickr_Data/Images\\3245070961_8977fdd548.jpg',
#  'Flickr_Data/Images\\3245460937_2710a82709.jpg',
#  'Flickr_Data/Images\\3245912109_fdeef6b456.jpg',
#  'Flickr_Data/Images\\3246991821_750a3097e2.jpg',
#  'Flickr_Data/Images\\3247052319_da8aba1983.jpg',
#  'Flickr_Data/Images\\3250695024_93e8ab7305.jpg',
#  'Flickr_Data/Images\\3251648670_9339943ba2.jpg',
#  'Flickr_Data/Images\\3251976937_20625dc2b8.jpg',
#  'Flickr_Data/Images\\3254817653_632e840423.jpg',
#  'Flickr_Data/Images\\3255482333_5bcee79f7e.jpg',
#  'Flickr_Data/Images\\3256043809_47258e0b3e.jpg',
#  'Flickr_Data/Images\\3256275785_9c3af57576.jpg',
#  'Flickr_Data/Images\\3258874419_23fec1bdc1.jpg',
#  'Flickr_Data/Images\\3259002340_707ce96858.jpg',
#  'Flickr_Data/Images\\3259666643_ae49524c81.jpg',
#  'Flickr_Data/Images\\3259991972_fce3ab18b2.jpg',
#  'Flickr_Data/Images\\3262075846_5695021d84.jpg',
#  'Flickr_Data/Images\\3263395801_5e4cee2b9e.jpg',
#  'Flickr_Data/Images\\3263497678_8bb688ca01.jpg',
#  'Flickr_Data/Images\\326456451_effadbbe49.jpg',
#  'Flickr_Data/Images\\3270691950_88583c3524.jpg',
#  'Flickr_Data/Images\\327415627_6313d32a64.jpg',
#  'Flickr_Data/Images\\3275704430_a75828048f.jpg',
#  'Flickr_Data/Images\\3280052365_c4644bf0a5.jpg',
#  'Flickr_Data/Images\\3281078518_630a7a7f4f.jpg',
#  'Flickr_Data/Images\\3285993030_87b0f1d202.jpg',
#  'Flickr_Data/Images\\3286822339_5535af6b93.jpg',
#  'Flickr_Data/Images\\3287549827_04dec6fb6e.jpg',
#  'Flickr_Data/Images\\3290105461_7590f23371.jpg',
#  'Flickr_Data/Images\\3294209955_a1f1e2cc19.jpg',
#  'Flickr_Data/Images\\3295391572_cbfde03a10.jpg',
#  'Flickr_Data/Images\\3295680663_af21ea648b.jpg',
#  'Flickr_Data/Images\\3299820401_c2589186c5.jpg',
#  'Flickr_Data/Images\\3301811927_a2797339e5.jpg',
#  'Flickr_Data/Images\\3301859683_2d5e4b40a3.jpg',
#  'Flickr_Data/Images\\3310067561_b92017acab.jpg',
#  'Flickr_Data/Images\\3315616181_15dd137e27.jpg',
#  'Flickr_Data/Images\\3316725440_9ccd9b5417.jpg',
#  'Flickr_Data/Images\\3317073508_7e13565c1b.jpg',
#  'Flickr_Data/Images\\3320032226_63390d74a6.jpg',
#  'Flickr_Data/Images\\3320356356_1497e53f80.jpg',
#  'Flickr_Data/Images\\3323988406_e3c8fce690.jpg',
#  'Flickr_Data/Images\\3325497914_f9014d615b.jpg',
#  'Flickr_Data/Images\\3328646934_5cca4cebce.jpg',
#  'Flickr_Data/Images\\3332467180_d72f9b067d.jpg',
#  'Flickr_Data/Images\\3333921867_6cc7d7c73d.jpg',
#  'Flickr_Data/Images\\3334537556_a2cf4e9b9a.jpg',
#  'Flickr_Data/Images\\3339140382_2e49bc324a.jpg',
#  'Flickr_Data/Images\\3344233740_c010378da7.jpg',
#  'Flickr_Data/Images\\3347666612_659e6e2207.jpg',
#  'Flickr_Data/Images\\3347798761_5c5260b000.jpg',
#  'Flickr_Data/Images\\3348385580_10b53391f9.jpg',
#  'Flickr_Data/Images\\3349451628_4249a21c8f.jpg',
#  'Flickr_Data/Images\\3350786891_6d39b234e9.jpg',
#  'Flickr_Data/Images\\3353036763_4cbeba03b2.jpg',
#  'Flickr_Data/Images\\3354330935_de75be9d2f.jpg',
#  'Flickr_Data/Images\\3354883962_170d19bfe4.jpg',
#  'Flickr_Data/Images\\3358558292_6ab14193ed.jpg',
#  'Flickr_Data/Images\\3358682439_be4b83544c.jpg',
#  'Flickr_Data/Images\\3359530430_249f51972c.jpg',
#  'Flickr_Data/Images\\3359551687_68f2f0212a.jpg',
#  'Flickr_Data/Images\\3360930596_1e75164ce6.jpg',
#  'Flickr_Data/Images\\3361990489_92244a58ef.jpg',
#  'Flickr_Data/Images\\3363750526_efcedc47a9.jpg',
#  'Flickr_Data/Images\\3364026240_645d533fda.jpg',
#  'Flickr_Data/Images\\3364151356_eecd07a23e.jpg',
#  'Flickr_Data/Images\\3364861247_d590fa170d.jpg',
#  'Flickr_Data/Images\\3365783912_e12c3510d8.jpg',
#  'Flickr_Data/Images\\3375070563_3c290a7991.jpg',
#  'Flickr_Data/Images\\3375549004_beee810e60.jpg',
#  'Flickr_Data/Images\\3375991133_87d7c40925.jpg',
#  'Flickr_Data/Images\\3384314832_dffc944152.jpg',
#  'Flickr_Data/Images\\3385246141_a263d1053e.jpg',
#  'Flickr_Data/Images\\3385593926_d3e9c21170.jpg',
#  'Flickr_Data/Images\\3387542157_81bfd00072.jpg',
#  'Flickr_Data/Images\\3388330419_85d72f7cda.jpg',
#  'Flickr_Data/Images\\3393343330_b13df4d8ec.jpg',
#  'Flickr_Data/Images\\339350939_6643bfb270.jpg',
#  'Flickr_Data/Images\\3393926562_66cc01b001.jpg',
#  'Flickr_Data/Images\\3396157719_6807d52a81.jpg',
#  'Flickr_Data/Images\\339658315_fbb178c252.jpg',
#  'Flickr_Data/Images\\3397220683_4aca010f86.jpg',
#  'Flickr_Data/Images\\3398746625_5199beea71.jpg',
#  'Flickr_Data/Images\\3399284917_721aefe2a7.jpg',
#  'Flickr_Data/Images\\3406930103_4db7b4dde0.jpg',
#  'Flickr_Data/Images\\3411393875_a9ff73c67a.jpg',
#  'Flickr_Data/Images\\3413571342_b9855795e2.jpg',
#  'Flickr_Data/Images\\3416091866_a96003d652.jpg',
#  'Flickr_Data/Images\\3421789737_f625dd17ed.jpg',
#  'Flickr_Data/Images\\3422458549_f3f3878dbf.jpg',
#  'Flickr_Data/Images\\3424424006_98f9d1921c.jpg',
#  'Flickr_Data/Images\\3425835357_204e620a66.jpg',
#  'Flickr_Data/Images\\3425851292_de92a072ee.jpg',
#  'Flickr_Data/Images\\3427118504_93126c83e0.jpg',
#  'Flickr_Data/Images\\3427233064_6af01bfc5c.jpg',
#  'Flickr_Data/Images\\3429956016_3c7e3096c2.jpg',
#  'Flickr_Data/Images\\3430607596_7e4f74e3ff.jpg',
#  'Flickr_Data/Images\\343218198_1ca90e0734.jpg',
#  'Flickr_Data/Images\\3432550415_e7b77232de.jpg',
#  'Flickr_Data/Images\\3433982387_3fa993cf5a.jpg',
#  'Flickr_Data/Images\\3435035138_af32890a4c.jpg',
#  'Flickr_Data/Images\\3436063693_15c8d377a2.jpg',
#  'Flickr_Data/Images\\3437147889_4cf26dd525.jpg',
#  'Flickr_Data/Images\\3437654963_c4fdc17e8b.jpg',
#  'Flickr_Data/Images\\3439382048_d2e23b2b4c.jpg',
#  'Flickr_Data/Images\\3442242092_e579538d82.jpg',
#  'Flickr_Data/Images\\3449114979_6cdc3e8da8.jpg',
#  'Flickr_Data/Images\\3450874870_c4dcf58fb3.jpg',
#  'Flickr_Data/Images\\3452127051_fa54a902b3.jpg',
#  'Flickr_Data/Images\\3453259666_9ecaa8bb4b.jpg',
#  'Flickr_Data/Images\\3456362961_d8f7e347a8.jpg',
#  'Flickr_Data/Images\\3457045393_2bbbb4e941.jpg',
#  'Flickr_Data/Images\\3458211052_bb73084398.jpg',
#  'Flickr_Data/Images\\3458559770_12cf9f134e.jpg',
#  'Flickr_Data/Images\\3459156091_c1879ebe28.jpg',
#  'Flickr_Data/Images\\3461041826_0e24cdf597.jpg',
#  'Flickr_Data/Images\\3462454965_a481809cea.jpg',
#  'Flickr_Data/Images\\3467219837_7d62213dec.jpg',
#  'Flickr_Data/Images\\3468694409_a51571d621.jpg',
#  'Flickr_Data/Images\\3470951932_27ed74eb0b.jpg',
#  'Flickr_Data/Images\\3471841031_a949645ba8.jpg',
#  'Flickr_Data/Images\\3472364264_dbde5a8d0a.jpg',
#  'Flickr_Data/Images\\3473264983_67917a931f.jpg',
#  'Flickr_Data/Images\\3474406285_01f3d24b71.jpg',
#  'Flickr_Data/Images\\3477715432_79d82487bb.jpg',
#  'Flickr_Data/Images\\3480051754_18e5802558.jpg',
#  'Flickr_Data/Images\\3482062809_3b694322c4.jpg',
#  'Flickr_Data/Images\\3482974845_db4f16befa.jpg',
#  'Flickr_Data/Images\\348380010_33bb0599ef.jpg',
#  'Flickr_Data/Images\\3484649669_7bfe62080b.jpg',
#  'Flickr_Data/Images\\3484832904_08619300d9.jpg',
#  'Flickr_Data/Images\\3485425825_c2f3446e73.jpg',
#  'Flickr_Data/Images\\3490736665_38710f4b91.jpg',
#  'Flickr_Data/Images\\3494394662_3edfd4a34c.jpg',
#  'Flickr_Data/Images\\3497224764_6e17544e0d.jpg',
#  'Flickr_Data/Images\\3498327617_d2e3db3ee3.jpg',
#  'Flickr_Data/Images\\3498997518_c2b16f0a0e.jpg',
#  'Flickr_Data/Images\\3499720588_c32590108e.jpg',
#  'Flickr_Data/Images\\3500136982_bf7a85531e.jpg',
#  'Flickr_Data/Images\\3502343542_f9b46688e5.jpg',
#  'Flickr_Data/Images\\3502993968_4ee36afb0e.jpg',
#  'Flickr_Data/Images\\3503623999_bbd5dcfb18.jpg',
#  'Flickr_Data/Images\\3503689049_63212220be.jpg',
#  'Flickr_Data/Images\\350443876_c9769f5734.jpg',
#  'Flickr_Data/Images\\3504881781_6a842e043b.jpg',
#  'Flickr_Data/Images\\3506468593_7e41a6d9f1.jpg',
#  'Flickr_Data/Images\\3506560025_8d0f4f9ac4.jpg',
#  'Flickr_Data/Images\\3507076266_8b17993fbb.jpg',
#  'Flickr_Data/Images\\3514019869_7de4ece2a5.jpg',
#  'Flickr_Data/Images\\3514179514_cbc3371b92.jpg',
#  'Flickr_Data/Images\\3516825206_5750824874.jpg',
#  'Flickr_Data/Images\\3518126579_e70e0cbb2b.jpg',
#  'Flickr_Data/Images\\3521374954_37371b49a4.jpg',
#  'Flickr_Data/Images\\3523471597_87e0bf3b21.jpg',
#  'Flickr_Data/Images\\3523474077_16e14bc54c.jpg',
#  'Flickr_Data/Images\\3523559027_a65619a34b.jpg',
#  'Flickr_Data/Images\\352382023_7605223d1c.jpg',
#  'Flickr_Data/Images\\3523874798_9ba2fa46e3.jpg',
#  'Flickr_Data/Images\\352981175_16ff5c07e4.jpg',
#  'Flickr_Data/Images\\3530843182_35af2c821c.jpg',
#  'Flickr_Data/Images\\353180303_6a24179c50.jpg',
#  'Flickr_Data/Images\\3532205154_5674b628ea.jpg',
#  'Flickr_Data/Images\\3537400880_8f410d747d.jpg',
#  'Flickr_Data/Images\\3538213870_9856a76b2a.jpg',
#  'Flickr_Data/Images\\3539767254_c598b8e6c7.jpg',
#  'Flickr_Data/Images\\3540416981_4e74f08cbb.jpg',
#  'Flickr_Data/Images\\3541474181_489f19fae7.jpg',
#  'Flickr_Data/Images\\3542484764_77d8920ec9.jpg',
#  'Flickr_Data/Images\\3544793763_b38546a5e8.jpg',
#  'Flickr_Data/Images\\3545586120_283d728a97.jpg',
#  'Flickr_Data/Images\\3545652636_0746537307.jpg',
#  'Flickr_Data/Images\\354642192_3b7666a2dd.jpg',
#  'Flickr_Data/Images\\3549583146_3e8bb2f7e9.jpg',
#  'Flickr_Data/Images\\3554634863_5f6f616639.jpg',
#  'Flickr_Data/Images\\3556598205_86c180769d.jpg',
#  'Flickr_Data/Images\\3558370311_5734a15890.jpg',
#  'Flickr_Data/Images\\3562050678_4196a7fff3.jpg',
#  'Flickr_Data/Images\\3564312955_716e86c48b.jpg',
#  'Flickr_Data/Images\\3564543247_05cdbc31cf.jpg',
#  'Flickr_Data/Images\\3565598162_56044bc2f7.jpg',
#  'Flickr_Data/Images\\3567061016_62768dcce1.jpg',
#  'Flickr_Data/Images\\3568197730_a071d7595b.jpg',
#  'Flickr_Data/Images\\3569406219_f37ebf7b92.jpg',
#  'Flickr_Data/Images\\3569979711_6507841268.jpg',
#  'Flickr_Data/Images\\3571147934_d1c8af1d6e.jpg',
#  'Flickr_Data/Images\\3572267708_9d8a81d4a4.jpg',
#  'Flickr_Data/Images\\3576259024_9c05b163aa.jpg',
#  'Flickr_Data/Images\\3578841731_f775cab089.jpg',
#  'Flickr_Data/Images\\3578914491_36019ba703.jpg',
#  'Flickr_Data/Images\\3582742297_1daa29968e.jpg',
#  'Flickr_Data/Images\\3584534971_b44f82c4b9.jpg',
#  'Flickr_Data/Images\\3584561689_b6eb24dd70.jpg',
#  'Flickr_Data/Images\\3584930205_a3f58a4b7c.jpg',
#  'Flickr_Data/Images\\3585487286_ef9a8d4c56.jpg',
#  'Flickr_Data/Images\\3585598356_8ce815bbb9.jpg',
#  'Flickr_Data/Images\\3589367895_5d3729e3ea.jpg',
#  'Flickr_Data/Images\\3589895574_ee08207d26.jpg',
#  'Flickr_Data/Images\\3591458156_f1a9a33918.jpg',
#  'Flickr_Data/Images\\3591462960_86045906bd.jpg',
#  'Flickr_Data/Images\\3592968286_b63c81bcd2.jpg',
#  'Flickr_Data/Images\\3592992234_6d3fe58a70.jpg',
#  'Flickr_Data/Images\\3593392955_a4125087f6.jpg',
#  'Flickr_Data/Images\\3595643050_d312e4b652.jpg',
#  'Flickr_Data/Images\\3596131692_91b8a05606.jpg',
#  'Flickr_Data/Images\\3597326009_3678a98a43.jpg',
#  'Flickr_Data/Images\\359837950_9e22ffe6c2.jpg',
#  'Flickr_Data/Images\\3601843201_4809e66909.jpg',
#  'Flickr_Data/Images\\3602838407_bf13e49243.jpg',
#  'Flickr_Data/Images\\3605061440_1d08c80a57.jpg',
#  'Flickr_Data/Images\\3605676864_0fb491267e.jpg',
#  'Flickr_Data/Images\\3609032038_005c789f64.jpg',
#  'Flickr_Data/Images\\3609645320_815c294b65.jpg',
#  'Flickr_Data/Images\\3610683688_bbe6d725ed.jpg',
#  'Flickr_Data/Images\\3613424631_3ae537624f.jpg',
#  'Flickr_Data/Images\\3613800013_5a54968ab0.jpg',
#  'Flickr_Data/Images\\3613955682_3860e116cf.jpg',
#  'Flickr_Data/Images\\3619416477_9d18580a14.jpg',
#  'Flickr_Data/Images\\3624327440_bef4f33f32.jpg',
#  'Flickr_Data/Images\\3627011534_485f667b10.jpg',
#  'Flickr_Data/Images\\3630332976_fdba22c50b.jpg',
#  'Flickr_Data/Images\\3630641436_8f9ac5b9b2.jpg',
#  'Flickr_Data/Images\\3631986552_944ea208fc.jpg',
#  'Flickr_Data/Images\\3635577874_48ebaac734.jpg',
#  'Flickr_Data/Images\\363617160_6cb0c723be.jpg',
#  'Flickr_Data/Images\\3639967449_137f48b43d.jpg',
#  'Flickr_Data/Images\\3640422448_a0f42e4559.jpg',
#  'Flickr_Data/Images\\3641022607_e7a5455d6c.jpg',
#  'Flickr_Data/Images\\3642220260_3aa8a52670.jpg',
#  'Flickr_Data/Images\\3647750811_395fbd397e.jpg',
#  'Flickr_Data/Images\\3651971126_309e6a5e22.jpg',
#  'Flickr_Data/Images\\3655074079_7df3812bc5.jpg',
#  'Flickr_Data/Images\\3655155990_b0e201dd3c.jpg',
#  'Flickr_Data/Images\\3655964639_21e76383d0.jpg',
#  'Flickr_Data/Images\\3657016761_d553e514d9.jpg',
#  'Flickr_Data/Images\\3658427967_6e2e57458d.jpg',
#  'Flickr_Data/Images\\3670907052_c827593564.jpg',
#  'Flickr_Data/Images\\3673165148_67f217064f.jpg',
#  'Flickr_Data/Images\\3677318686_b018862bb7.jpg',
#  'Flickr_Data/Images\\3685328542_ab999b83bb.jpg',
#  'Flickr_Data/Images\\3686924335_3c51e8834a.jpg',
#  'Flickr_Data/Images\\3688858505_e8afd1475d.jpg',
#  'Flickr_Data/Images\\3692593096_fbaea67476.jpg',
#  'Flickr_Data/Images\\3692892751_f6574e2700.jpg',
#  'Flickr_Data/Images\\3694064560_467683205b.jpg',
#  'Flickr_Data/Images\\3694093650_547259731e.jpg',
#  'Flickr_Data/Images\\3694991841_141804da1f.jpg',
#  'Flickr_Data/Images\\3696698390_989f1488e7.jpg',
#  'Flickr_Data/Images\\3697359692_8a5cdbe4fe.jpg',
#  'Flickr_Data/Images\\3701291852_373ea46bb6.jpg',
#  'Flickr_Data/Images\\3702436188_2c26192fd0.jpg',
#  'Flickr_Data/Images\\370614351_98b8a166b9.jpg',
#  'Flickr_Data/Images\\370713359_7560808550.jpg',
#  'Flickr_Data/Images\\3708177171_529bb4ff1d.jpg',
#  'Flickr_Data/Images\\3715469645_6d1dc019b3.jpg',
#  'Flickr_Data/Images\\3716244806_97d5a1fb61.jpg',
#  'Flickr_Data/Images\\3718964174_cb2dc1615e.jpg',
#  'Flickr_Data/Images\\3720366614_dfa8fe1088.jpg',
#  'Flickr_Data/Images\\3725202807_12fbfdd207.jpg',
#  'Flickr_Data/Images\\3727752439_907795603b.jpg',
#  'Flickr_Data/Images\\3729525173_7f984ed776.jpg',
#  'Flickr_Data/Images\\373394550_1b2296b8c4.jpg',
#  'Flickr_Data/Images\\3737539561_d1dc161040.jpg',
#  'Flickr_Data/Images\\3741462565_cc35966b7a.jpg',
#  'Flickr_Data/Images\\3741827382_71e93298d0.jpg',
#  'Flickr_Data/Images\\3745451546_fc8ec70cbd.jpg',
#  'Flickr_Data/Images\\375392855_54d46ed5c8.jpg',
#  'Flickr_Data/Images\\3767841911_6678052eb6.jpg',
#  'Flickr_Data/Images\\384577800_fc325af410.jpg',
#  'Flickr_Data/Images\\387830531_e89c192b92.jpg',
#  'Flickr_Data/Images\\391579205_c8373b5411.jpg',
#  'Flickr_Data/Images\\396360611_941e5849a3.jpg',
#  'Flickr_Data/Images\\398662202_97e5819b79.jpg',
#  'Flickr_Data/Images\\400851260_5911898657.jpg',
#  'Flickr_Data/Images\\401079494_562454c4d6.jpg',
#  'Flickr_Data/Images\\405615014_03be7ef618.jpg',
#  'Flickr_Data/Images\\410453140_5401bf659a.jpg',
#  'Flickr_Data/Images\\415793623_6c1225ae27.jpg',
#  'Flickr_Data/Images\\416106657_cab2a107a5.jpg',
#  'Flickr_Data/Images\\416788726_5b4eb1466e.jpg',
#  'Flickr_Data/Images\\416960865_048fd3f294.jpg',
#  'Flickr_Data/Images\\421322723_3470543368.jpg',
#  'Flickr_Data/Images\\421730441_6b2267fd31.jpg',
#  'Flickr_Data/Images\\422763475_0bc814dac6.jpg',
#  'Flickr_Data/Images\\424416723_19c56cb365.jpg',
#  'Flickr_Data/Images\\424779662_568f9606d0.jpg',
#  'Flickr_Data/Images\\429851331_b248ca01cd.jpg',
#  'Flickr_Data/Images\\430173345_86388d8822.jpg',
#  'Flickr_Data/Images\\434792818_56375e203f.jpg',
#  'Flickr_Data/Images\\435827376_4384c3005a.jpg',
#  'Flickr_Data/Images\\436009777_440c7679a1.jpg',
#  'Flickr_Data/Images\\439037721_cdf1fc7358.jpg',
#  'Flickr_Data/Images\\444057017_f1e0fcaef7.jpg',
#  'Flickr_Data/Images\\444481722_690d0cadcf.jpg',
#  'Flickr_Data/Images\\447111935_5af98563e3.jpg',
#  'Flickr_Data/Images\\448252603_7d928c900e.jpg',
#  'Flickr_Data/Images\\448658518_eec0b648a6.jpg',
#  'Flickr_Data/Images\\452419961_6d42ab7000.jpg',
#  'Flickr_Data/Images\\460935487_75b2da7854.jpg',
#  'Flickr_Data/Images\\461505235_590102a5bf.jpg',
#  'Flickr_Data/Images\\463978865_c87c6ca84c.jpg',
#  'Flickr_Data/Images\\464251704_b0f0c4c87a.jpg',
#  'Flickr_Data/Images\\466956209_2ffcea3941.jpg',
#  'Flickr_Data/Images\\468102269_135938e209.jpg',
#  'Flickr_Data/Images\\468310111_d9396abcbd.jpg',
#  'Flickr_Data/Images\\468608014_09fd20eb9b.jpg',
#  'Flickr_Data/Images\\470373679_98dceb19e7.jpg',
#  'Flickr_Data/Images\\473220329_819a913bbb.jpg',
#  'Flickr_Data/Images\\476233374_e1396998ef.jpg',
#  'Flickr_Data/Images\\476759700_8911f087f8.jpg',
#  'Flickr_Data/Images\\480505313_2dc686e5db.jpg',
#  'Flickr_Data/Images\\485245061_5a5de43e20.jpg',
#  'Flickr_Data/Images\\486712504_36be449055.jpg',
#  'Flickr_Data/Images\\486917990_72bd4069af.jpg',
#  'Flickr_Data/Images\\488356951_b3b77ad832.jpg',
#  'Flickr_Data/Images\\488408004_a1e26d4886.jpg',
#  'Flickr_Data/Images\\488590040_35a3e96c89.jpg',
#  'Flickr_Data/Images\\491405109_798222cfd0.jpg',
#  'Flickr_Data/Images\\493109089_468e105233.jpg',
#  'Flickr_Data/Images\\493621130_152bdd4e91.jpg',
#  'Flickr_Data/Images\\494792770_2c5f767ac0.jpg',
#  'Flickr_Data/Images\\494921598_af73bda568.jpg',
#  'Flickr_Data/Images\\496110746_a93ca191ae.jpg',
#  'Flickr_Data/Images\\497791037_93499238d8.jpg',
#  'Flickr_Data/Images\\498444334_a680d318a1.jpg',
#  'Flickr_Data/Images\\500446858_125702b296.jpg',
#  'Flickr_Data/Images\\505929313_7668f021ab.jpg',
#  'Flickr_Data/Images\\506367606_7cca2bba9b.jpg',
#  'Flickr_Data/Images\\506738508_327efdf9c3.jpg',
#  'Flickr_Data/Images\\509123893_07b8ea82a9.jpg',
#  'Flickr_Data/Images\\509778093_21236bb64d.jpg',
#  'Flickr_Data/Images\\510531976_90bbee22a2.jpg',
#  'Flickr_Data/Images\\512101751_05a6d93e19.jpg',
#  'Flickr_Data/Images\\514990193_2d2422af2c.jpg',
#  'Flickr_Data/Images\\522063319_33827f1627.jpg',
#  'Flickr_Data/Images\\523985664_c866af4850.jpg',
#  'Flickr_Data/Images\\524105255_b346f288be.jpg',
#  'Flickr_Data/Images\\524282699_71e678a6bd.jpg',
#  'Flickr_Data/Images\\525863257_053333e612.jpg',
#  'Flickr_Data/Images\\53043785_c468d6f931.jpg',
#  'Flickr_Data/Images\\532457586_bddfc5251d.jpg',
#  'Flickr_Data/Images\\533483374_86c5d4c13e.jpg',
#  'Flickr_Data/Images\\533713007_bf9f3e25b4.jpg',
#  'Flickr_Data/Images\\533979933_a95b03323b.jpg',
#  'Flickr_Data/Images\\534875358_6ea30d3091.jpg',
#  'Flickr_Data/Images\\535830521_aa971319fc.jpg',
#  'Flickr_Data/Images\\537532165_e4b7c0e61a.jpg',
#  'Flickr_Data/Images\\537559285_29be110134.jpg',
#  'Flickr_Data/Images\\539751252_2bd88c456b.jpg',
#  'Flickr_Data/Images\\540721368_12ac732c6c.jpg',
#  'Flickr_Data/Images\\541063517_35044c554a.jpg',
#  'Flickr_Data/Images\\542179694_e170e9e465.jpg',
#  'Flickr_Data/Images\\542317719_ed4dd95dc2.jpg',
#  'Flickr_Data/Images\\543007912_23fc735b99.jpg',
#  'Flickr_Data/Images\\544576742_283b65fa0d.jpg',
#  'Flickr_Data/Images\\54501196_a9ac9d66f2.jpg',
#  'Flickr_Data/Images\\561417861_8e25d0c0e8.jpg',
#  'Flickr_Data/Images\\561940436_64d6fc125d.jpg',
#  'Flickr_Data/Images\\56489627_e1de43de34.jpg',
#  'Flickr_Data/Images\\566397227_a469e9e415.jpg',
#  'Flickr_Data/Images\\57422853_b5f6366081.jpg',
#  'Flickr_Data/Images\\583174725_6b522b621f.jpg',
#  'Flickr_Data/Images\\624742559_ff467d8ebc.jpg',
#  'Flickr_Data/Images\\670609997_5c7fdb3f0b.jpg',
#  'Flickr_Data/Images\\700884207_d3ec546494.jpg',
#  'Flickr_Data/Images\\70995350_75d0698839.jpg',
#  'Flickr_Data/Images\\732468337_a37075225e.jpg',
#  'Flickr_Data/Images\\745880539_cd3f948837.jpg',
#  'Flickr_Data/Images\\747921928_48eb02aab2.jpg',
#  'Flickr_Data/Images\\751109943_2a7f8e117f.jpg',
#  'Flickr_Data/Images\\751737218_b89839a311.jpg',
#  'Flickr_Data/Images\\754852108_72f80d421f.jpg',
#  'Flickr_Data/Images\\757046028_ff5999f91b.jpg',
#  'Flickr_Data/Images\\757332692_6866ae545c.jpg',
#  'Flickr_Data/Images\\758921886_55a351dd67.jpg',
#  'Flickr_Data/Images\\766099402_cdda6964f0.jpg',
#  'Flickr_Data/Images\\771048251_602e5e8f45.jpg',
#  'Flickr_Data/Images\\791338571_7f38510bf7.jpg',
#  'Flickr_Data/Images\\799486353_f665d7b0f0.jpg',
#  'Flickr_Data/Images\\801607443_f15956d1ce.jpg',
#  'Flickr_Data/Images\\820169182_f5e78d7d19.jpg',
#  'Flickr_Data/Images\\86412576_c53392ef80.jpg',
#  'Flickr_Data/Images\\872622575_ba1d3632cc.jpg',
#  'Flickr_Data/Images\\880220939_0ef1c37f1f.jpg',
#  'Flickr_Data/Images\\888425986_e4b6c12324.jpg',
#  'Flickr_Data/Images\\909191414_1cf5d85821.jpg',
#  'Flickr_Data/Images\\909808296_23c427022d.jpg',
#  'Flickr_Data/Images\\917574521_74fab68514.jpg',
#  'Flickr_Data/Images\\925491651_57df3a5b36.jpg',
#  'Flickr_Data/Images\\929679367_ff8c7df2ee.jpg',
#  'Flickr_Data/Images\\96420612_feb18fc6c6.jpg',
#  'Flickr_Data/Images\\968081289_cdba83ce2e.jpg',
#  'Flickr_Data/Images\\979383193_0a542a059d.jpg',
#  'Flickr_Data/Images\\997722733_0cb5439472.jpg']

# %%
def load_clean_descriptions(filename, dataset):
    doc = load_doc(filename)
    descriptions = dict()
    for line in doc.split('\n'):
        tokens = line.split()
        image_id, image_desc = tokens[0], tokens[1:]
        if image_id in dataset:
            if image_id not in descriptions:
                descriptions[image_id] = list()
            desc = 'startseq ' + ' '.join(image_desc) + ' endseq'
            descriptions[image_id].append(desc)
    return descriptions

train_descriptions = load_clean_descriptions('descriptions.txt', train)
print('Descriptions: train=%d' % len(train_descriptions))
# Out:
# Descriptions: train=6000

# %%
def preprocess(image_path):
    img = image.load_img(image_path, target_size=(299, 299))
    x = image.img_to_array(img)
    x = np.expand_dims(x, axis=0)
    x = preprocess_input(x)
    return x

# %%
model = InceptionV3(weights='imagenet')

# %%
model_new = Model(model.input, model.layers[-2].output)

# %%
def encode(image):
    image = preprocess(image) 
    fea_vec = model_new.predict(image) 
    fea_vec = np.reshape(fea_vec, fea_vec.shape[1]) 
    return fea_vec
print(len(images))
# Out:
# 19

# %%
start = time()
encoding_train = {}
for img in train_img:
    encoding_train[img[len(images):]] = encode(img)
print("Time taken in seconds =", time()-start)
# Out:
# Time taken in seconds = 1751.5639326572418

# %%
with open("pickle/encoded_train_images.pkl", "wb") as encoded_pickle:
    pickle.dump(encoding_train, encoded_pickle)

# %%
start = time()
encoding_test = {}
for img in test_img:
    encoding_test[img[len(images):]] = encode(img)
print("Time taken in seconds =", time()-start)
print(img)
# Out:
# Time taken in seconds = 299.13367319107056
# Flickr_Data/Images\997722733_0cb5439472.jpg

# %%
with open("pickle/encoded_test_images.pkl", "wb") as encoded_pickle:
    pickle.dump(encoding_test, encoded_pickle)

# %%
train_features = load(open("pickle/encoded_train_images.pkl", "rb"))
print('Photos: train=%d' % len(train_features))
# Out:
# Photos: train=6000

# %%
all_train_captions = []
for key, val in train_descriptions.items():
    for cap in val:
        all_train_captions.append(cap)
len(all_train_captions)
# Out:
# 30000

# %%
word_count_threshold = 10
word_counts = {}
nsents = 0
for sent in all_train_captions:
    nsents += 1
    for w in sent.split(' '):
        word_counts[w] = word_counts.get(w, 0) + 1

vocab = [w for w in word_counts if word_counts[w] >= word_count_threshold]
print('preprocessed words %d -> %d' % (len(word_counts), len(vocab)))
# Out:
# preprocessed words 7578 -> 1651

# %%
ixtoword = {}
wordtoix = {}

ix = 1
for w in vocab:
    wordtoix[w] = ix
    ixtoword[ix] = w
    ix += 1

# %%
vocab_size = len(ixtoword) + 1 # one for appended 0's
vocab_size
# Out:
# 1652

# %%
def to_lines(descriptions):
    all_desc = list()
    for key in descriptions.keys():
        [all_desc.append(d) for d in descriptions[key]]
    return all_desc

def max_length(descriptions):
    lines = to_lines(descriptions)
    return max(len(d.split()) for d in lines)

max_length = max_length(train_descriptions)
print('Description Length: %d' % max_length)
# Out:
# Description Length: 34

# %%
def data_generator(descriptions, photos, wordtoix, max_length, num_photos_per_batch):
    X1, X2, y = list(), list(), list()
    n=0
    while 1:
        for key, desc_list in descriptions.items():
            n+=1
            photo = photos[key+'.jpg']
            for desc in desc_list:
                seq = [wordtoix[word] for word in desc.split(' ') if word in wordtoix]
                for i in range(1, len(seq)):t
                    in_seq, out_seq = seq[:i], seq[i]
                    
                    in_seq = pad_sequences([in_seq], maxlen=max_length)[0]
                   
                    out_seq = to_categorical([out_seq], num_classes=vocab_size)[0]
                  
                    X1.append(photo)
                    X2.append(in_seq)
                    y.append(out_seq)
           
            if n==num_photos_per_batch:
                yield [[array(X1), array(X2)], array(y)]
                X1, X2, y = list(), list(), list()
                n=0

# %%
glove_dir = 'glove6b200d'
embeddings_index = {} 
f = open(os.path.join(glove_dir, 'glove.6B.200d.txt'), encoding="utf-8")

for line in f:
    values = line.split()
    word = values[0]
    coefs = np.asarray(values[1:], dtype='float32')
    embeddings_index[word] = coefs
f.close()
print('Found %s word vectors.' % len(embeddings_index))
# Out:
# Found 400000 word vectors.

# %%
embedding_dim = 200

embedding_matrix = np.zeros((vocab_size, embedding_dim))

for word, i in wordtoix.items():
    embedding_vector = embeddings_index.get(word)
    if embedding_vector is not None:
        embedding_matrix[i] = embedding_vector

# %%
inputs1 = Input(shape=(2048,))
fe1 = Dropout(0.5)(inputs1)
fe2 = Dense(256, activation='relu')(fe1)
inputs2 = Input(shape=(max_length,))
se1 = Embedding(vocab_size, embedding_dim, mask_zero=True)(inputs2)
se2 = Dropout(0.5)(se1)
se3 = LSTM(256)(se2)
decoder1 = add([fe2, se3])
decoder2 = Dense(256, activation='relu')(decoder1)
outputs = Dense(vocab_size, activation='softmax')(decoder2)
model = Model(inputs=[inputs1, inputs2], outputs=outputs)

# %%
model.summary()
# Out:
# Model: "model_2"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_3 (InputLayer)            (None, 34)           0
# __________________________________________________________________________________________________
# input_2 (InputLayer)            (None, 2048)         0
# __________________________________________________________________________________________________
# embedding_1 (Embedding)         (None, 34, 200)      330400      input_3[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 2048)         0           input_2[0][0]
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, 34, 200)      0           embedding_1[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 256)          524544      dropout_1[0][0]
# __________________________________________________________________________________________________
# lstm_1 (LSTM)                   (None, 256)          467968      dropout_2[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 256)          0           dense_1[0][0]
#                                                                  lstm_1[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 256)          65792       add_1[0][0]
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 1652)         424564      dense_2[0][0]
# ==================================================================================================
# Total params: 1,813,268
# Trainable params: 1,813,268
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
model.layers[2]

# %%
model.layers[2].set_weights([embedding_matrix])
model.layers[2].trainable = False

# %%
model.compile(loss='categorical_crossentropy', optimizer='adam')

# %%
epochs = 40
number_pics_per_bath = 3
steps = len(train_descriptions)//number_pics_per_bath

# %%
for i in range(epochs):
    generator = data_generator(train_descriptions, train_features, wordtoix, max_length, number_pics_per_bath)
    model.fit_generator(generator, epochs=1, steps_per_epoch=steps, verbose=1)
    model.save('./model_weights/model_' + str(i) + '.h5')
# Out:
# Epoch 1/1
#  631/2000 [========>.....................] - ETA: 8:49 - loss: 4.6508
